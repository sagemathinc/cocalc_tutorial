# %% [markdown]
# ## Assignment 1
#
# Modify the code below so that the points and line are green.

# %%
# We'll use pandas to load the data as a dataframe
import pandas as pd
df = pd.read_csv('../../data/somedata/somedata.csv', sep=',',header=None)

# %%
# Plot using matplotlib
import matplotlib
# %matplotlib inline
somedata_plot = df.plot(x=0,y=1,style='r--o')
somedata_plot.set_xlabel("x")
somedata_plot.set_ylabel("y");
